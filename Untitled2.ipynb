# %%
import os
import tensorflow as tf
import pandas as pd
from  tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.

# %%
tf.enable_eager_execution()

# %%
PATH = '/media/nvidia/Elements/panoptic-toolbox/171204_pose1/rotationnet4/'
test_resized_directory = os.path.join(PATH, 'test_resized/images/')
test_directory = os.path.join(PATH, 'test/images/')
target_directory = os.path.join(PATH, 'rotationnet_results/images/')

# %%
result_csv = pd.read_csv(test_resized_directory + 'test.csv')
result_csv
# Out:
#        Unnamed: 0           file_name  label      result
# 0               0  01_01_00000187.jpg   -137 -137.034060
# 1               1  01_01_00000193.jpg     51   47.824127
# 2               2  01_01_00000197.jpg    -61  -64.797480
# 3               3  01_01_00000205.jpg     56   60.213737
# 4               4  01_01_00000209.jpg     90   94.022285
# 5               5  01_01_00000214.jpg     30   33.085850
# 6               6  01_01_00000215.jpg     87   89.979620
# 7               7  01_01_00000222.jpg    -95  -87.793290
# 8               8  01_01_00000223.jpg     85   88.754840
# 9               9  01_01_00000227.jpg    170  167.609450
# 10             10  01_01_00000248.jpg    133  137.792080
# 11             11  01_01_00000256.jpg   -148 -147.200360
# 12             12  01_01_00000258.jpg    -48  -49.860590
# 13             13  01_01_00000267.jpg    -47  -46.545074
# 14             14  01_01_00000268.jpg     67   72.146040
# 15             15  01_01_00000272.jpg     36   33.878750
# 16             16  01_01_00000274.jpg    105  121.000000
# 17             17  01_01_00000284.jpg    -47  -44.953907
# 18             18  01_01_00000288.jpg   -105  -99.360115
# 19             19  01_01_00000297.jpg   -148 -145.859800
# 20             20  01_01_00000303.jpg     98  101.572140
# 21             21  01_01_00000305.jpg   -105  -91.423110
# 22             22  01_01_00000306.jpg    -40  -41.501830
# 23             23  01_01_00000307.jpg     19   13.603746
# 24             24  01_01_00000315.jpg    -97  -96.905820
# 25             25  01_01_00000316.jpg     52   46.505220
# 26             26  01_01_00000319.jpg     -5   -5.893470
# 27             27  01_01_00000320.jpg   -125 -125.802310
# 28             28  01_04_00000184.jpg    107  115.170906
# 29             29  01_04_00000188.jpg     28   27.207020
# ...           ...                 ...    ...         ...
# 40386       40386  20_14_00020809.jpg     10    6.278088
# 40387       40387  20_14_00020829.jpg    -82  -79.244720
# 40388       40388  20_14_00020830.jpg      3    7.411533
# 40389       40389  20_14_00020834.jpg    121  126.335640
# 40390       40390  20_14_00020837.jpg    105  108.771030
# 40391       40391  20_14_00020840.jpg    -13  -15.298868
# 40392       40392  20_14_00020849.jpg      7    9.120565
# 40393       40393  20_14_00020850.jpg     31   28.398438
# 40394       40394  20_14_00020855.jpg     72   76.673560
# 40395       40395  20_14_00020871.jpg    140  151.880080
# 40396       40396  20_14_00020877.jpg    -91  -92.276960
# 40397       40397  20_14_00020878.jpg    -49  -46.099430
# 40398       40398  20_17_00020793.jpg    -25  -18.835888
# 40399       40399  20_17_00020798.jpg    -42  -36.303750
# 40400       40400  20_17_00020799.jpg    174 -176.761960
# 40401       40401  20_17_00020807.jpg     16   15.662453
# 40402       40402  20_17_00020811.jpg   -131 -129.391920
# 40403       40403  20_17_00020816.jpg     11   13.779474
# 40404       40404  20_17_00020819.jpg   -171 -162.955350
# 40405       40405  20_17_00020820.jpg     56   50.408630
# 40406       40406  20_17_00020838.jpg      0    3.519105
# 40407       40407  20_17_00020849.jpg    125  121.591000
# 40408       40408  20_17_00020856.jpg     36   35.202370
# 40409       40409  20_17_00020857.jpg   -150 -146.445630
# 40410       40410  20_17_00020858.jpg     77   81.648100
# 40411       40411  20_17_00020859.jpg    -50  -46.415367
# 40412       40412  20_17_00020873.jpg    -80  -80.375300
# 40413       40413  20_17_00020875.jpg    148  135.303820
# 40414       40414  20_17_00020878.jpg   -156 -150.198260
# 40415       40415  20_17_00020880.jpg    -32  -27.065706
#
# [40416 rows x 4 columns]

# %%
def rotate_image_for_openpose(result_csv, test_directory, target_directory):
    for i, j in zip(result_csv.file_name, result_csv.result):
        image = tf.io.read_file(test_directory + i)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.contrib.image.rotate(image, -j * 0.01745329251, interpolation='BILINEAR')
        tf.keras.preprocessing.image.save_img(target_directory + i, image, file_format = 'jpeg')

# %%
rotate_image_for_openpose(result_csv, test_directory, target_directory)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
